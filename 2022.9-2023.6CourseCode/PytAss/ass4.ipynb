# %% [markdown]
# ## Q1

# %% [markdown]
# #### Implement a lambda function to determine whether the 'larger' integer of these two positive integer inputs is divisible by the 'smaller' integer.

# %%
divisible = lambda a, b: a%b == 0 if  a>b else b%a == 0
# Complete the expression here #

# you can run the following script to verify your function
# a, b = [int(val) for val in input().split(' ')]
# print(divisible(a , b))
# Out:
# 4 2
# True

# %% [markdown]
# ## Q2

# %% [markdown]
# ![q2.png](attachment:q2.png)

# %%
from functools import reduce
from math import exp
nums = [float(x) for x in input().split()]
y_k = [exp(o_k) for o_k in nums]
y_num = sum(y_k)
# print(y_num)
res = []
for o_j in nums:
    y = exp(o_j) / y_num
    res.append(y)
res = ('%.2f' % r for r in res)
res = [str(n) for n in res]
res = ' '.join(res)
print(res)
# Out:
# 1.58 2.41 0.03 0.56 2.66
# 33.066333089229964
# 0.15 0.34 0.03 0.05 0.43

# %% [markdown]
# ## Q3

# %% [markdown]
# ![q3.png](attachment:q3.png)

# %%
def f(n):
    # write your code here
    if n ==1:
        return 1
    else:
        x = f(n-1)
        return(1/(n-1)) * (x + 1/x)

n = int(input())
print("%.2f"%f(n))

# %% [markdown]
# ## Q4

# %% [markdown]
# #### Write a function to find the longest common prefix string amongst several strings. Write a function to find the longest common prefix string amongst several strings.

# %%
def longestCommonPrefix(strs):
    #write your code here
    result=""
    return result

strs = [str(x) for x in input().split()]
print(longestCommonPrefix(strs))

# %% [markdown]
# ## Q5

# %% [markdown]
# #### Input any number of integers (separated by commas), then use the map function the lamda function to calculate the square of each number and output them as a list.

# %%
#use map
nums = [int(x) for x in input().split(',')]
# Return square of n
def sq(n):
    return n * n

# We square all numbers using map()
result = map(sq, nums)
print(list(result))
# Out:
# 2,3,5,6,7
# [4, 9, 25, 36, 49]

# %% [markdown]
# ## Q6

# %% [markdown]
# #### Input multiple integers (separated by commas) and use the reduce function to calculate the result of their cumulative multiplication,

# %%
from functools import reduce 
ints = [int(x) for x in input().split(",") ]
# Return multiplication of n
def mult(n1, n2):
    return n1 * n2

# We mult. all numbers using reduce()
result = reduce(mult, ints)
print(result)
# Out:
# 1,2,4,5
# 40

# %% [markdown]
# ## Q7

# %% [markdown]
# #### Input any number of characters (separated by commas), then use the 'map' function to change the lowercase English characters into uppercase English characters and output them as a list

# %%
chars = input().split(',')
# Return upper of n
def up(c):
    return c.upper()
# We upper all numbers using map()
result = map(up, chars)
print(list(result))
# Out:
# Y,u,c,x,1,t
# ['Y', 'U', 'C', 'X', '1', 'T']

# %% [markdown]
# ## Q8

# %% [markdown]
# #### Use lambda function and sorted function to sort the five strings in the following list according to string length or alphabetical order.
# #### If you input 0, the strings are sorted by length. If you enter 1, it will be sorted according to the alphabetical order.

# %%
chars = ['yuio1234', 'abcd', 'zzbbrt', 'rt', '12tyrrtrttrtryryrtbfgah']
flag = int(input())
if flag == 0:
    print(sorted(chars, key=lambda x: len(x)))
#implement this lambda function))
else:
    print(sorted(chars, key=lambda x: x[0]))
#implement this lambda function))
# Out:
# 1
# ['12tyrrtrttrtryryrtbfgah', 'abcd', 'rt', 'yuio1234', 'zzbbrt']

# %% [markdown]
# ## Q9

# %% [markdown]
# #### Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.

# %% [markdown]
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# |Symbol|Value|
# |:-:|:-:|
# I    |       1
# V    |      5
# X    |      10
# L    |       50
# C    |      100
# D    |      500
# M    |     1000

# %%
# dict
Xdict = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
# main
s=input()
chars = [Xdict[c] for c in s]
# chars = sorted(chars)
res = 0
for c in range(1, len(chars)):
    if chars[c-1] < chars[c]:
    # 小字符在前
        res -= chars[c-1]
    else:
        res += chars[c-1]
res += chars[-1]
print(res)
# Out:
# MCMXCIV
# 1994
